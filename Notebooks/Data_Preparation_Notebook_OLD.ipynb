# %% [markdown]
# # Data Preparation Notebook
#
# This Jupyter notebook contains steps for preparing the dataset for further analysis and modeling.
# It includes data cleaning, handling missing data, and (pre-)processing data.
#
# ## Steps Included:
# 1. Converting Date and Time Columns
# 2. Transforming Numeric Data
# 3. Handling Missing Data
# 4. Cleaning String Data
# 5. Data Quality Assessment
#
# Let's start by loading the dataset and necessary libraries.

# %%
import pandas as pd

# Load the dataset
file_path = 'combined_data.csv' 
data = pd.read_csv(file_path)

# Display the first few rows of the dataset
data.head()
# Out:
#    NLSitNummer DatumFileBegin DatumFileEind TijdFileBegin TijdFileEind  \
# 0      3346718     2023-01-11    2023-01-11      17:22:32     17:44:04
# 1      3346719     2023-01-11    2023-01-11      17:22:32     17:43:00
# 2      3346720     2023-01-11    2023-01-11      17:22:32     17:59:00
# 3      3346721     2023-01-11    2023-01-11      17:22:32     17:30:04
# 4      3346722     2023-01-11    2023-01-11      17:22:32     17:24:00
#
#   FileZwaarte GemLengte FileDuur HectometerKop HectometerStaart  ...  \
# 0      58,340  2709,000   21,533         116,5            114,5  ...
# 1      74,363  3633,000   20,467           0,0              3,7  ...
# 2     213,030  5842,000   36,467          70,0             66,6  ...
# 3      20,768  2757,000    7,533           9,8             12,2  ...
# 4       3,080  2100,000    1,467         223,2            225,3  ...
#
#       TrajVan          TrajNaar               OorzaakGronddetail  \
# 0     Utrecht  's-Hertogenbosch           Defect(e) voertuig(en)
# 1  Amersfoort           Utrecht  Spitsfile (geen oorzaak gemeld)
# 2      Muiden          Lelystad  Spitsfile (geen oorzaak gemeld)
# 3        Aken            Geleen  Spitsfile (geen oorzaak gemeld)
# 4    Enschede        Varsseveld  Spitsfile (geen oorzaak gemeld)
#
#                                       OorzaakVerloop OorzaakCodeVerloop  \
# 0  [Geen oorzaakcode opgegeven door VWM 2], [Defe...       [000], [BKD]
# 1           [Geen oorzaakcode opgegeven door VWM 20]              [000]
# 2           [Geen oorzaakcode opgegeven door VWM 36]              [000]
# 3            [Geen oorzaakcode opgegeven door VWM 8]              [000]
# 4            [Geen oorzaakcode opgegeven door VWM 1]              [000]
#
#   OorzaakCode                        Oorzaak_1            Oorzaak_2  \
# 0         BKD           Defect(e) voertuig(en)      Defect voertuig
# 1         001  Spitsfile (geen oorzaak gemeld)  Geen oorzaak gemeld
# 2         001  Spitsfile (geen oorzaak gemeld)  Geen oorzaak gemeld
# 3         001  Spitsfile (geen oorzaak gemeld)  Geen oorzaak gemeld
# 4         001  Spitsfile (geen oorzaak gemeld)  Geen oorzaak gemeld
#
#                       Oorzaak_3         Oorzaak_4
# 0  Incident (gestrand voertuig)          Incident
# 1                        Drukte  Hoge intensiteit
# 2                        Drukte  Hoge intensiteit
# 3                        Drukte  Hoge intensiteit
# 4                        Drukte  Hoge intensiteit
#
# [5 rows x 26 columns]

# %% [markdown]
# ## Convert Date and Time Columns
#
# We'll convert columns with dates and times into a standard datetime format.

# %%
# Converting columns to datetime format
date_columns = ['DatumFileBegin', 'DatumFileEind']
time_columns = ['TijdFileBegin', 'TijdFileEind']

for col in date_columns:
    data[col] = pd.to_datetime(data[col])

for col in time_columns:
    data[col] = pd.to_datetime(data[col], format='%H:%M:%S').dt.time

# Display the updated dataset
data.head()
# Out:
#    NLSitNummer DatumFileBegin DatumFileEind TijdFileBegin TijdFileEind  \
# 0      3346718     2023-01-11    2023-01-11      17:22:32     17:44:04
# 1      3346719     2023-01-11    2023-01-11      17:22:32     17:43:00
# 2      3346720     2023-01-11    2023-01-11      17:22:32     17:59:00
# 3      3346721     2023-01-11    2023-01-11      17:22:32     17:30:04
# 4      3346722     2023-01-11    2023-01-11      17:22:32     17:24:00
#
#   FileZwaarte GemLengte FileDuur HectometerKop HectometerStaart  ...  \
# 0      58,340  2709,000   21,533         116,5            114,5  ...
# 1      74,363  3633,000   20,467           0,0              3,7  ...
# 2     213,030  5842,000   36,467          70,0             66,6  ...
# 3      20,768  2757,000    7,533           9,8             12,2  ...
# 4       3,080  2100,000    1,467         223,2            225,3  ...
#
#       TrajVan          TrajNaar               OorzaakGronddetail  \
# 0     Utrecht  's-Hertogenbosch           Defect(e) voertuig(en)
# 1  Amersfoort           Utrecht  Spitsfile (geen oorzaak gemeld)
# 2      Muiden          Lelystad  Spitsfile (geen oorzaak gemeld)
# 3        Aken            Geleen  Spitsfile (geen oorzaak gemeld)
# 4    Enschede        Varsseveld  Spitsfile (geen oorzaak gemeld)
#
#                                       OorzaakVerloop OorzaakCodeVerloop  \
# 0  [Geen oorzaakcode opgegeven door VWM 2], [Defe...       [000], [BKD]
# 1           [Geen oorzaakcode opgegeven door VWM 20]              [000]
# 2           [Geen oorzaakcode opgegeven door VWM 36]              [000]
# 3            [Geen oorzaakcode opgegeven door VWM 8]              [000]
# 4            [Geen oorzaakcode opgegeven door VWM 1]              [000]
#
#   OorzaakCode                        Oorzaak_1            Oorzaak_2  \
# 0         BKD           Defect(e) voertuig(en)      Defect voertuig
# 1         001  Spitsfile (geen oorzaak gemeld)  Geen oorzaak gemeld
# 2         001  Spitsfile (geen oorzaak gemeld)  Geen oorzaak gemeld
# 3         001  Spitsfile (geen oorzaak gemeld)  Geen oorzaak gemeld
# 4         001  Spitsfile (geen oorzaak gemeld)  Geen oorzaak gemeld
#
#                       Oorzaak_3         Oorzaak_4
# 0  Incident (gestrand voertuig)          Incident
# 1                        Drukte  Hoge intensiteit
# 2                        Drukte  Hoge intensiteit
# 3                        Drukte  Hoge intensiteit
# 4                        Drukte  Hoge intensiteit
#
# [5 rows x 26 columns]

# %% [markdown]
# ## Transform Numeric Data
#
# Transform columns with numeric data stored as strings into numeric formats.

# %%
# Convert numeric data stored as strings to numeric format
numeric_columns = ['FileZwaarte', 'GemLengte']

for col in numeric_columns:
    data[col] = data[col].str.replace(',', '').astype(float)

# Display the updated dataset
data.head()
# Out:
#    NLSitNummer DatumFileBegin DatumFileEind TijdFileBegin TijdFileEind  \
# 0      3346718     2023-01-11    2023-01-11      17:22:32     17:44:04
# 1      3346719     2023-01-11    2023-01-11      17:22:32     17:43:00
# 2      3346720     2023-01-11    2023-01-11      17:22:32     17:59:00
# 3      3346721     2023-01-11    2023-01-11      17:22:32     17:30:04
# 4      3346722     2023-01-11    2023-01-11      17:22:32     17:24:00
#
#    FileZwaarte  GemLengte FileDuur HectometerKop HectometerStaart  ...  \
# 0      58340.0  2709000.0   21,533         116,5            114,5  ...
# 1      74363.0  3633000.0   20,467           0,0              3,7  ...
# 2     213030.0  5842000.0   36,467          70,0             66,6  ...
# 3      20768.0  2757000.0    7,533           9,8             12,2  ...
# 4       3080.0  2100000.0    1,467         223,2            225,3  ...
#
#       TrajVan          TrajNaar               OorzaakGronddetail  \
# 0     Utrecht  's-Hertogenbosch           Defect(e) voertuig(en)
# 1  Amersfoort           Utrecht  Spitsfile (geen oorzaak gemeld)
# 2      Muiden          Lelystad  Spitsfile (geen oorzaak gemeld)
# 3        Aken            Geleen  Spitsfile (geen oorzaak gemeld)
# 4    Enschede        Varsseveld  Spitsfile (geen oorzaak gemeld)
#
#                                       OorzaakVerloop OorzaakCodeVerloop  \
# 0  [Geen oorzaakcode opgegeven door VWM 2], [Defe...       [000], [BKD]
# 1           [Geen oorzaakcode opgegeven door VWM 20]              [000]
# 2           [Geen oorzaakcode opgegeven door VWM 36]              [000]
# 3            [Geen oorzaakcode opgegeven door VWM 8]              [000]
# 4            [Geen oorzaakcode opgegeven door VWM 1]              [000]
#
#   OorzaakCode                        Oorzaak_1            Oorzaak_2  \
# 0         BKD           Defect(e) voertuig(en)      Defect voertuig
# 1         001  Spitsfile (geen oorzaak gemeld)  Geen oorzaak gemeld
# 2         001  Spitsfile (geen oorzaak gemeld)  Geen oorzaak gemeld
# 3         001  Spitsfile (geen oorzaak gemeld)  Geen oorzaak gemeld
# 4         001  Spitsfile (geen oorzaak gemeld)  Geen oorzaak gemeld
#
#                       Oorzaak_3         Oorzaak_4
# 0  Incident (gestrand voertuig)          Incident
# 1                        Drukte  Hoge intensiteit
# 2                        Drukte  Hoge intensiteit
# 3                        Drukte  Hoge intensiteit
# 4                        Drukte  Hoge intensiteit
#
# [5 rows x 26 columns]

# %% [markdown]
# ## Handling Missing Data
#
# Identifying and addressing missing data in the dataset.

# %%
# Check for missing values
missing_data = data.isnull().sum()
missing_data[missing_data > 0]
# Out:
# Series([], dtype: int64)

# %%
# Drop rows with any missing values
data = data.dropna()

# Verify the operation by checking for missing values again
missing_data_after = data.isnull().sum()
missing_data_after[missing_data_after > 0]
# Out:
# Series([], dtype: int64)

# %% [markdown]
# ## Cleaning String Data
#
# Trimming unnecessary whitespaces and handling new lines in string columns.

# %%
# Cleaning string columns
string_columns = data.select_dtypes(include='object').columns

for col in string_columns:
    data[col] = data[col].astype(str).str.strip()

# Display the updated dataset
data.head()
# Out:
#    NLSitNummer DatumFileBegin DatumFileEind TijdFileBegin TijdFileEind  \
# 0      3346718     2023-01-11    2023-01-11      17:22:32     17:44:04
# 1      3346719     2023-01-11    2023-01-11      17:22:32     17:43:00
# 2      3346720     2023-01-11    2023-01-11      17:22:32     17:59:00
# 3      3346721     2023-01-11    2023-01-11      17:22:32     17:30:04
# 4      3346722     2023-01-11    2023-01-11      17:22:32     17:24:00
#
#    FileZwaarte  GemLengte FileDuur HectometerKop HectometerStaart  ...  \
# 0      58340.0  2709000.0   21,533         116,5            114,5  ...
# 1      74363.0  3633000.0   20,467           0,0              3,7  ...
# 2     213030.0  5842000.0   36,467          70,0             66,6  ...
# 3      20768.0  2757000.0    7,533           9,8             12,2  ...
# 4       3080.0  2100000.0    1,467         223,2            225,3  ...
#
#       TrajVan          TrajNaar               OorzaakGronddetail  \
# 0     Utrecht  's-Hertogenbosch           Defect(e) voertuig(en)
# 1  Amersfoort           Utrecht  Spitsfile (geen oorzaak gemeld)
# 2      Muiden          Lelystad  Spitsfile (geen oorzaak gemeld)
# 3        Aken            Geleen  Spitsfile (geen oorzaak gemeld)
# 4    Enschede        Varsseveld  Spitsfile (geen oorzaak gemeld)
#
#                                       OorzaakVerloop OorzaakCodeVerloop  \
# 0  [Geen oorzaakcode opgegeven door VWM 2], [Defe...       [000], [BKD]
# 1           [Geen oorzaakcode opgegeven door VWM 20]              [000]
# 2           [Geen oorzaakcode opgegeven door VWM 36]              [000]
# 3            [Geen oorzaakcode opgegeven door VWM 8]              [000]
# 4            [Geen oorzaakcode opgegeven door VWM 1]              [000]
#
#   OorzaakCode                        Oorzaak_1            Oorzaak_2  \
# 0         BKD           Defect(e) voertuig(en)      Defect voertuig
# 1         001  Spitsfile (geen oorzaak gemeld)  Geen oorzaak gemeld
# 2         001  Spitsfile (geen oorzaak gemeld)  Geen oorzaak gemeld
# 3         001  Spitsfile (geen oorzaak gemeld)  Geen oorzaak gemeld
# 4         001  Spitsfile (geen oorzaak gemeld)  Geen oorzaak gemeld
#
#                       Oorzaak_3         Oorzaak_4
# 0  Incident (gestrand voertuig)          Incident
# 1                        Drukte  Hoge intensiteit
# 2                        Drukte  Hoge intensiteit
# 3                        Drukte  Hoge intensiteit
# 4                        Drukte  Hoge intensiteit
#
# [5 rows x 26 columns]

# %% [markdown]
# ## Removing Square Brackets in 'OorzaakVerloop' Column
#
# In the `OorzaakVerloop` column, each entry is enclosed within square brackets, which are not necessary for our analysis and may interfere with certain data processing tasks. To clean this data, we will remove the square brackets from each entry in this column.
#
# This step enhances the readability of the data and ensures that any subsequent text processing or analysis on this column does not get affected by these extraneous characters.

# %%
# Remove square brackets from 'OorzaakVerloop' column
data['OorzaakVerloop'] = data['OorzaakVerloop'].str.replace('[', '', regex=False)
data['OorzaakVerloop'] = data['OorzaakVerloop'].str.replace(']', '', regex=False)

# Display the updated 'OorzaakVerloop' column
data['OorzaakVerloop'].head()
# Out:
# 0    Geen oorzaakcode opgegeven door VWM 2, Defect(...
# 1               Geen oorzaakcode opgegeven door VWM 20
# 2               Geen oorzaakcode opgegeven door VWM 36
# 3                Geen oorzaakcode opgegeven door VWM 8
# 4                Geen oorzaakcode opgegeven door VWM 1
# Name: OorzaakVerloop, dtype: object

# %% [markdown]
# # Dataset Translation from Dutch to English
#
# ## Purpose
# The dataset originally contains information in Dutch, which is not accessible or understandable to all potential users, especially those who are not proficient in Dutch. To make this dataset more universally accessible and easier to work with, we will translate it from Dutch to English.
#
# ## Scope
# 1. **Column Headers**: All column headers will be translated from Dutch to English to provide a clear understanding of the dataset's structure.
# 2. **Column Contents**: The textual contents of each column will also be translated. This step is crucial for columns containing descriptive information or categorical data.
#
# ## Method
# We will use the `googletrans` library for this translation. This library provides a convenient way to access Google Translate's capabilities programmatically.
#
# ## Considerations
# - The translation process can be time-consuming for large datasets.
# - Automated translations may not always be perfect, and there could be nuances in the text that are not captured accurately.
# - We will ensure to handle any translation errors and retain the original Dutch text where the translation is not feasible or produces unclear results.
#
# By translating the dataset, we aim to enhance its accessibility and usability for a broader audience, facilitating better data understanding and analysis.

# %%
from googletrans import Translator
import pandas as pd


# Create a Translator object
translator = Translator()

# Function to translate text
def translate_text(text, src_language='nl', dest_language='en'):
    """Translate the specified text from src_language to dest_language."""
    try:
        return translator.translate(text, src=src_language, dest=dest_language).text
    except Exception as e:
        print(f"Error while translating '{text}': {e}")
        return text  # Return original text if translation fails

# Translate column headers
translated_headers = [translate_text(header) for header in data.columns]

# Create a new DataFrame with translated headers
translated_data = pd.DataFrame(data.values, columns=translated_headers)

# Check the translated headers
print(translated_data.columns)
# Out:
# Error while translating 'NLSitNummer': 'NoneType' object has no attribute 'group'
# Error while translating 'DatumFileBegin': 'NoneType' object has no attribute 'group'
# Error while translating 'DatumFileEind': 'NoneType' object has no attribute 'group'
# Error while translating 'TijdFileBegin': 'NoneType' object has no attribute 'group'
# Error while translating 'TijdFileEind': 'NoneType' object has no attribute 'group'
# Error while translating 'FileZwaarte': 'NoneType' object has no attribute 'group'
# Error while translating 'GemLengte': 'NoneType' object has no attribute 'group'
# Error while translating 'FileDuur': 'NoneType' object has no attribute 'group'
# Error while translating 'HectometerKop': 'NoneType' object has no attribute 'group'
# Error while translating 'HectometerStaart': 'NoneType' object has no attribute 'group'
# Error while translating 'RouteLet': 'NoneType' object has no attribute 'group'
# Error while translating 'RouteNum': 'NoneType' object has no attribute 'group'
# Error while translating 'RouteOms': 'NoneType' object has no attribute 'group'
# Error while translating 'hectometreringsrichting': 'NoneType' object has no attribute 'group'
# Error while translating 'KopWegvakVan': 'NoneType' object has no attribute 'group'
# Error while translating 'KopWegvakNaar': 'NoneType' object has no attribute 'group'
# Error while translating 'TrajVan': 'NoneType' object has no attribute 'group'
# Error while translating 'TrajNaar': 'NoneType' object has no attribute 'group'
# Error while translating 'OorzaakGronddetail': 'NoneType' object has no attribute 'group'
# Error while translating 'OorzaakVerloop': 'NoneType' object has no attribute 'group'
# Error while translating 'OorzaakCodeVerloop': 'NoneType' object has no attribute 'group'
# Error while translating 'OorzaakCode': 'NoneType' object has no attribute 'group'
# Error while translating 'Oorzaak_1': 'NoneType' object has no attribute 'group'
# Error while translating 'Oorzaak_2': 'NoneType' object has no attribute 'group'
# Error while translating 'Oorzaak_3': 'NoneType' object has no attribute 'group'
# Error while translating 'Oorzaak_4': 'NoneType' object has no attribute 'group'
# Index(['NLSitNummer', 'DatumFileBegin', 'DatumFileEind', 'TijdFileBegin',
#        'TijdFileEind', 'FileZwaarte', 'GemLengte', 'FileDuur', 'HectometerKop',
#        'HectometerStaart', 'RouteLet', 'RouteNum', 'RouteOms',
#        'hectometreringsrichting', 'KopWegvakVan', 'KopWegvakNaar', 'TrajVan',
#        'TrajNaar', 'OorzaakGronddetail', 'OorzaakVerloop',
#        'OorzaakCodeVerloop', 'OorzaakCode', 'Oorzaak_1', 'Oorzaak_2',
#        'Oorzaak_3', 'Oorzaak_4'],
#       dtype='object')

# %% [markdown]
# The translation given is not very accurate, so it will be done manually

# %%
translated_headers = {
   'NLSitNummer': 'NL Site Number',
    'DatumFileBegin': 'File Start Date',
    'DatumFileEind': 'File End Date',
    'TijdFileBegin': 'File Start Time',
    'TijdFileEind': 'File End Time',
    'FileZwaarte': 'File Severity',
    'GemLengte': 'Average Length',
    'FileDuur': 'File Duration',
    'HectometerKop': 'Hectometer Head',
    'HectometerStaart': 'Hectometer Tail',
    'RouteLet': 'Route Letter',
    'RouteNum': 'Route Number',
    'RouteOms': 'Route Description',
    'hectometreringsrichting': 'Hectometering Direction',
    'KopWegvakVan': 'Head Road Section From',
    'KopWegvakNaar': 'Head Road Section To',
    'TrajVan': 'Trajectory From',
    'TrajNaar': 'Trajectory To',
    'OorzaakGronddetail': 'Cause Ground Detail',
    'OorzaakVerloop': 'Cause Progression',
    'OorzaakCodeVerloop': 'Cause Code Progression',
    'OorzaakCode': 'Cause Code',
    'Oorzaak_1': 'Cause 1',
    'Oorzaak_2': 'Cause 2',
    'Oorzaak_3': 'Cause 3',
    'Oorzaak_4': 'Cause 4',
  
}

# Replace the headers in the dataset
data.rename(columns=translated_headers, inplace=True)

# Save the translated dataset
data.to_csv('./translated_header_combined_data.csv', index=False)

# %% [markdown]
# now lets trasnlate the content of the column Hectometering Direction

# %%
from googletrans import Translator, LANGUAGES
import pandas as pd

# Load your dataset
data = pd.read_csv('./translated_header_combined_data.csv')

# Create a Translator object
translator = Translator()

# Function to translate text and convert to lowercase
def translate_and_lowercase(text, src_language='nl', dest_language='en'):
    """Translate the specified text from src_language to dest_language and convert to lowercase."""
    try:
        translated_text = translator.translate(text, src=src_language, dest=dest_language).text
        return translated_text.lower()  # Convert to lowercase
    except Exception as e:
        print(f"Error while translating '{text}': {e}")
        return None  # Return None if translation fails

# Column name in your dataset that needs translation
column_to_translate = 'Hectometering Direction'

# Translate unique values in the column and convert to lowercase
unique_values = data[column_to_translate].unique()
translations = {val: translate_and_lowercase(val) for val in unique_values if isinstance(val, str)}

# Ensure all translations were successful
data.to_csv('./translated_hectometering_direction_combined_data.csv', index=False)

data.head(10)
# Out:
# Error while translating 'oplopend': 'NoneType' object has no attribute 'group'
# Error while translating 'aflopend': 'NoneType' object has no attribute 'group'
#    NL Site Number File Start Date File End Date File Start Time File End Time  \
# 0         3346718      2023-01-11    2023-01-11        17:22:32      17:44:04
# 1         3346719      2023-01-11    2023-01-11        17:22:32      17:43:00
# 2         3346720      2023-01-11    2023-01-11        17:22:32      17:59:00
# 3         3346721      2023-01-11    2023-01-11        17:22:32      17:30:04
# 4         3346722      2023-01-11    2023-01-11        17:22:32      17:24:00
# 5         3346809      2023-01-11    2023-01-11        17:36:33      17:39:00
# 6         3346811      2023-01-11    2023-01-11        17:36:33      17:38:00
# 7         3346812      2023-01-11    2023-01-11        17:36:33      17:38:00
# 8         3346813      2023-01-11    2023-01-11        17:36:33      17:38:00
# 9         3346816      2023-01-11    2023-01-11        17:37:32      17:39:00
#
#    File Severity  Average Length File Duration Hectometer Head  \
# 0        58340.0       2709000.0        21,533           116,5
# 1        74363.0       3633000.0        20,467             0,0
# 2       213030.0       5842000.0        36,467            70,0
# 3        20768.0       2757000.0         7,533             9,8
# 4         3080.0       2100000.0         1,467           223,2
# 5         5145.0       2100000.0         2,450            59,6
# 6         4205.0       2900000.0         1,450             8,1
# 7         3425.0       2362000.0         1,450           142,6
# 8         3915.0       2700000.0         1,450            21,3
# 9         3373.0       2300000.0         1,467            22,5
#
#   Hectometer Tail  ...   Trajectory From     Trajectory To  \
# 0           114,5  ...           Utrecht  's-Hertogenbosch
# 1             3,7  ...        Amersfoort           Utrecht
# 2            66,6  ...            Muiden          Lelystad
# 3            12,2  ...              Aken            Geleen
# 4           225,3  ...          Enschede        Varsseveld
# 5            57,5  ...         Amsterdam           Utrecht
# 6             5,2  ...         Amsterdam         Wassenaar
# 7           140,2  ...  's-Hertogenbosch               Oss
# 8            24,0  ...            Almelo            Zwolle
# 9            24,7  ...             Breda         Rotterdam
#
#                Cause Ground Detail  \
# 0           Defect(e) voertuig(en)
# 1  Spitsfile (geen oorzaak gemeld)
# 2  Spitsfile (geen oorzaak gemeld)
# 3  Spitsfile (geen oorzaak gemeld)
# 4  Spitsfile (geen oorzaak gemeld)
# 5  Spitsfile (geen oorzaak gemeld)
# 6  Spitsfile (geen oorzaak gemeld)
# 7  Spitsfile (geen oorzaak gemeld)
# 8  Spitsfile (geen oorzaak gemeld)
# 9  Spitsfile (geen oorzaak gemeld)
#
#                                    Cause Progression Cause Code Progression  \
# 0  Geen oorzaakcode opgegeven door VWM 2, Defect(...           [000], [BKD]
# 1             Geen oorzaakcode opgegeven door VWM 20                  [000]
# 2             Geen oorzaakcode opgegeven door VWM 36                  [000]
# 3              Geen oorzaakcode opgegeven door VWM 8                  [000]
# 4              Geen oorzaakcode opgegeven door VWM 1                  [000]
# 5              Geen oorzaakcode opgegeven door VWM 2                  [000]
# 6              Geen oorzaakcode opgegeven door VWM 1                  [000]
# 7              Geen oorzaakcode opgegeven door VWM 1                  [000]
# 8              Geen oorzaakcode opgegeven door VWM 1                  [000]
# 9              Geen oorzaakcode opgegeven door VWM 1                  [000]
#
#   Cause Code                          Cause 1              Cause 2  \
# 0        BKD           Defect(e) voertuig(en)      Defect voertuig
# 1        001  Spitsfile (geen oorzaak gemeld)  Geen oorzaak gemeld
# 2        001  Spitsfile (geen oorzaak gemeld)  Geen oorzaak gemeld
# 3        001  Spitsfile (geen oorzaak gemeld)  Geen oorzaak gemeld
# 4        001  Spitsfile (geen oorzaak gemeld)  Geen oorzaak gemeld
# 5        001  Spitsfile (geen oorzaak gemeld)  Geen oorzaak gemeld
# 6        001  Spitsfile (geen oorzaak gemeld)  Geen oorzaak gemeld
# 7        001  Spitsfile (geen oorzaak gemeld)  Geen oorzaak gemeld
# 8        001  Spitsfile (geen oorzaak gemeld)  Geen oorzaak gemeld
# 9        001  Spitsfile (geen oorzaak gemeld)  Geen oorzaak gemeld
#
#                         Cause 3           Cause 4
# 0  Incident (gestrand voertuig)          Incident
# 1                        Drukte  Hoge intensiteit
# 2                        Drukte  Hoge intensiteit
# 3                        Drukte  Hoge intensiteit
# 4                        Drukte  Hoge intensiteit
# 5                        Drukte  Hoge intensiteit
# 6                        Drukte  Hoge intensiteit
# 7                        Drukte  Hoge intensiteit
# 8                        Drukte  Hoge intensiteit
# 9                        Drukte  Hoge intensiteit
#
# [10 rows x 26 columns]

# %% [markdown]
# The changes were succesfull.

# %% [markdown]
# next is Cause Ground Detail, additionaly I added some custom translation

# %%
from googletrans import Translator
import pandas as pd

# Load your dataset
data = pd.read_csv('./translated_hectometering_direction_combined_data.csv')

# Create a Translator object
translator = Translator()

# Custom translations
custom_translations = {
    'File buiten spits (geen oorzaak gemeld)': 'Traffic jam outside rush hour (no cause reported)',
    'Spitsfile (geen oorzaak gemeld)': 'Rush hour traffic jam (no cause reported)',
    'Spitsfile (geen oorzaak gemeld) met gevonden werk in Spin': 'Rush hour traffic jam (no cause reported) with work found in Spin',
    'Afremmend verkeer als gevolg van kijkers naar  ongeval(len)': 'Traffic slowing down as a result of watching accident(s)',
    'Werkzaamheden (en daarna ongeval)': 'Work (and then accident)',

}

# Function to translate text and convert to lowercase
def translate_and_lowercase(text, src_language='nl', dest_language='en'):
    """Translate the specified text from src_language to dest_language and convert to lowercase."""
    # Use custom translation if available
    if text in custom_translations:
        return custom_translations[text].lower()

    # Otherwise, use the translator
    try:
        translated_text = translator.translate(text, src=src_language, dest=dest_language).text
        return translated_text.lower()  # Convert to lowercase
    except Exception as e:
        print(f"Error while translating '{text}': {e}")
        return None  # Return None if translation fails

# Column name in your dataset that needs translation
column_to_translate = 'Cause Ground Detail'

# Translate unique values in the column and convert to lowercase
unique_values = data[column_to_translate].unique()
translations = {val: translate_and_lowercase(val) for val in unique_values if isinstance(val, str)}

# Define a function to extract the 'VWM' part
def extract_vwm(value):
    if pd.isna(value) or not isinstance(value, str):
        return value  # Return the value as is if it's NaN or not a string
    # Extract 'VWM' followed by any number of digits
    vwm_part = pd.Series(value).str.extract(r'(VWM \d+)')[0]
    return vwm_part

# Apply the function to the 'Cause Progression' column
data['Cause Progression'] = data['Cause Progression'].apply(extract_vwm)

if not pd.api.types.is_numeric_dtype(data['Hectometer Head']):
    data['Hectometer Head'] = data['Hectometer Head'].str.replace(',', '.').astype(float)
if not pd.api.types.is_numeric_dtype(data['Hectometer Tail']):
    data['Hectometer Tail'] = data['Hectometer Tail'].str.replace(',', '.').astype(float)

data.drop(columns=["Cause Code Progression", "Cause Code", "Cause 1", "Cause 2", "Cause 3", "Cause 4", "Head Road Section From", "Head Road Section To", "Cause Progression" ], inplace=True)

# # Ensure all translations were successful
# if None not in translations.values():
#     # Apply the translations to the column
#     data[column_to_translate] = data[column_to_translate].map(translations)

#     # Save the translated dataset
#     )
# else:
#     print("Translation failed for some values. Please check the errors.")
    
data[column_to_translate] = data[column_to_translate].map(translations)
data.to_csv('./data_final_yes.csv', index=False)

data.head(10)
# Out:
# Error while translating 'Defect(e) voertuig(en)': 'NoneType' object has no attribute 'group'
# Error while translating 'Ongeval (in een spitsfile)': 'NoneType' object has no attribute 'group'
# Error while translating 'Ongeval(len)': 'NoneType' object has no attribute 'group'
# Error while translating 'Ongeval met vrachtwagen(s)': 'NoneType' object has no attribute 'group'
# Error while translating 'Spitsfile (met defect voertuig)': 'NoneType' object has no attribute 'group'
# Error while translating 'Ongeval op aansluitende weg': 'NoneType' object has no attribute 'group'
# Error while translating 'Incident op aansluitende weg': 'NoneType' object has no attribute 'group'
# Error while translating 'Schade aan wegmeubilair': 'NoneType' object has no attribute 'group'
# Error while translating 'Wegwerkzaamheden': 'NoneType' object has no attribute 'group'
# Error while translating 'Opruimingswerkzaamheden': 'NoneType' object has no attribute 'group'
# Error while translating 'Spitsfile (met ongeval)': 'NoneType' object has no attribute 'group'
# Error while translating 'Defecte vrachtwagen(s)': 'NoneType' object has no attribute 'group'
# Error while translating 'Opgehoogde werkzaamheden': 'NoneType' object has no attribute 'group'
# Error while translating 'Eerder(e) ongeval(len)': 'NoneType' object has no attribute 'group'
# Error while translating 'Wegdek in slechte toestand': 'NoneType' object has no attribute 'group'
# Error while translating 'Ongeval vrachtwagen (met opruim/berging)': 'NoneType' object has no attribute 'group'
# Error while translating 'Ongeval (met opruim/berging)': 'NoneType' object has no attribute 'group'
# Error while translating 'Defect voertuig (met opruim/berging)': 'NoneType' object has no attribute 'group'
# Error while translating 'Onwelwording': 'NoneType' object has no attribute 'group'
# Error while translating 'Defect voertuig (object op de weg)': 'NoneType' object has no attribute 'group'
# Error while translating 'Grenscontrole': 'NoneType' object has no attribute 'group'
# Error while translating 'Water op de weg': 'NoneType' object has no attribute 'group'
# Error while translating 'Ongeval op aansluitende weg (met spitsfile)': 'NoneType' object has no attribute 'group'
# Error while translating 'Spitsfile (met ongeval op aansluitende weg)': 'NoneType' object has no attribute 'group'
# Error while translating 'Falen DVM (en spitsfile)': 'NoneType' object has no attribute 'group'
# Error while translating 'Spitsfile (met vrachtwagen)': 'NoneType' object has no attribute 'group'
# Error while translating 'Defecte vrachtwagen (met opruim/berging)': 'NoneType' object has no attribute 'group'
# Error while translating 'Spoedreparatie': 'NoneType' object has no attribute 'group'
# Error while translating 'Ongeval en (file buiten spits zonder oorzaak)': 'NoneType' object has no attribute 'group'
# Error while translating 'Opruimwerkzaamheden': 'NoneType' object has no attribute 'group'
# Error while translating 'Spoedtransport': 'NoneType' object has no attribute 'group'
# Error while translating 'Defecte vrachtwagen (met ongeval)': 'NoneType' object has no attribute 'group'
# Error while translating 'Spitsfile (met object op de weg)': 'NoneType' object has no attribute 'group'
# Error while translating 'Defect voertuig (met spitsfile)': 'NoneType' object has no attribute 'group'
# Error while translating 'Te ho(o)g(e) voertuig(en)': 'NoneType' object has no attribute 'group'
# Error while translating 'Veiligheidsincident': 'NoneType' object has no attribute 'group'
# Error while translating 'Opruim/bergingswerkzaamheden (in een spitsfile)': 'NoneType' object has no attribute 'group'
# Error while translating 'Geschaarde trekker(s) met oplegger': 'NoneType' object has no attribute 'group'
# Error while translating 'Defect voertuig (en daarna ongeval)': 'NoneType' object has no attribute 'group'
# Error while translating 'Object op de weg (met opruim/berging)': 'NoneType' object has no attribute 'group'
# Error while translating 'Ongeval (en daarna defect voertuig)': 'NoneType' object has no attribute 'group'
# Error while translating 'File buiten spits zonder oorzaak (met werkzaamheden)': 'NoneType' object has no attribute 'group'
# Error while translating 'Defecte vrachtwagen (met incident op aansluitende weg)': 'NoneType' object has no attribute 'group'
# Error while translating 'Spitsfile (met een incident)': 'NoneType' object has no attribute 'group'
# Error while translating 'Brugopening': 'NoneType' object has no attribute 'group'
# Error while translating 'Defect voertuig (en ander incident)': 'NoneType' object has no attribute 'group'
# Error while translating 'Ongeval vrachtwagen (in een spitsfile)': 'NoneType' object has no attribute 'group'
# Error while translating 'Eerder pechgeval': 'NoneType' object has no attribute 'group'
# Error while translating 'Incident op aansluitende weg en spitsfile': 'NoneType' object has no attribute 'group'
# Error while translating 'Sneeuw op de weg': 'NoneType' object has no attribute 'group'
# Error while translating 'Winterse buien': 'NoneType' object has no attribute 'group'
# Error while translating 'Defecte vrachtwagen (in een spitsfile)': 'NoneType' object has no attribute 'group'
# Error while translating 'Brandend(e) voertuig(en)': 'NoneType' object has no attribute 'group'
# Error while translating 'Spitsfile (defect voertuig en berging)': 'NoneType' object has no attribute 'group'
# Error while translating 'Olie op het wegdek': 'NoneType' object has no attribute 'group'
# Error while translating 'Ongeval (met spoedreparatie)': 'NoneType' object has no attribute 'group'
# Error while translating 'Voorwerpen op de weg': 'NoneType' object has no attribute 'group'
# Error while translating 'Spitsfile': 'NoneType' object has no attribute 'group'
# Error while translating 'Gladde weg': 'NoneType' object has no attribute 'group'
# Error while translating 'Ongeval (met opruim/berging en files buiten spits zonder oorzaak)': 'NoneType' object has no attribute 'group'
# Error while translating 'Ongeval vrachtwagen (en incident)': 'NoneType' object has no attribute 'group'
# Error while translating 'Ongeval (met ongeval op aanslutiende weg)': 'NoneType' object has no attribute 'group'
# Error while translating 'Defecte bus(sen)': 'NoneType' object has no attribute 'group'
# Error while translating 'Spitsfile (met incident op aansluitende weg)': 'NoneType' object has no attribute 'group'
# Error while translating 'Ongeval op aansluitende weg (met file zonder oorzaak)': 'NoneType' object has no attribute 'group'
# Error while translating 'Incident op provinciale weg': 'NoneType' object has no attribute 'group'
# Error while translating 'Extra verkeersdrukte door ongeval elders': 'NoneType' object has no attribute 'group'
# Error while translating 'Afgevallen lading(en)': 'NoneType' object has no attribute 'group'
# Error while translating 'Defecte vrachtwagen (en files buiten spits zonder oorzaak)': 'NoneType' object has no attribute 'group'
# Error while translating 'Geschaarde aanhanger(s)': 'NoneType' object has no attribute 'group'
# Error while translating 'spoedreparatie (en spitsfile)': 'NoneType' object has no attribute 'group'
# Error while translating 'spoedreparatie en files buiten spits zonder oorzaak': 'NoneType' object has no attribute 'group'
# Error while translating 'File op omleidingsroute (en file zonder oorzaak)': 'NoneType' object has no attribute 'group'
# Error while translating 'Evenementen (en files buiten spits zonder oorzaak)': 'NoneType' object has no attribute 'group'
# Error while translating 'Werkzaamheden op aansluitende weg': 'NoneType' object has no attribute 'group'
# Error while translating 'Gekanteld(e) vrachtwagen(s)': 'NoneType' object has no attribute 'group'
# Error while translating 'Rechter tunnelbuis afgesloten': 'NoneType' object has no attribute 'group'
# Error while translating 'Beschadigde geleiderail': 'NoneType' object has no attribute 'group'
# Error while translating 'Dieren op de weg': 'NoneType' object has no attribute 'group'
# Error while translating 'Recreatie- en vakantieverkeer': 'NoneType' object has no attribute 'group'
# Error while translating 'Spitsfile (met ongeval vrachtauto)': 'NoneType' object has no attribute 'group'
# Error while translating 'Er ligt rommel op de weg': 'NoneType' object has no attribute 'group'
# Error while translating 'Ongeval (met opruim/berging) (en defecte vrachtwagen)': 'NoneType' object has no attribute 'group'
# Error while translating 'Politieactie': 'NoneType' object has no attribute 'group'
# Error while translating 'Ongeval op aansluitende weg (en incident op aansluitende weg)': 'NoneType' object has no attribute 'group'
# Error while translating 'Modder op het wegdek': 'NoneType' object has no attribute 'group'
# Error while translating 'Object op de weg (in een spitsfile)': 'NoneType' object has no attribute 'group'
# Error while translating 'Ongeval (met ander incident)': 'NoneType' object has no attribute 'group'
# Error while translating 'Extra verkeersdrukte door verkeer dat een omleiding volgt': 'NoneType' object has no attribute 'group'
# Error while translating 'Ongeval op provinciale weg': 'NoneType' object has no attribute 'group'
# Error while translating 'Evenement': 'NoneType' object has no attribute 'group'
# Error while translating 'Voetbalwedstrijd': 'NoneType' object has no attribute 'group'
# Error while translating 'Mensen op de weg': 'NoneType' object has no attribute 'group'
# Error while translating 'Ongeval (met object op de weg)': 'NoneType' object has no attribute 'group'
# Error while translating 'Brugopening (met file buiten spits zonder oorzaak)': 'NoneType' object has no attribute 'group'
# Error while translating 'Technische storing': 'NoneType' object has no attribute 'group'
# Error while translating 'Afrit afgesloten': 'NoneType' object has no attribute 'group'
# Error while translating 'Ongeval (met incident op aanslutiende weg)': 'NoneType' object has no attribute 'group'
# Error while translating 'Ongeval op aansluitende weg (met defect voertuig)': 'NoneType' object has no attribute 'group'
# Error while translating 'Eerder ongeval op aansluitende weg': 'NoneType' object has no attribute 'group'
# Error while translating 'Defecte vrachtwagen (met ongeval en opruim/berging)': 'NoneType' object has no attribute 'group'
# Error while translating 'Defecte vrachtwagen (object op de weg)': 'NoneType' object has no attribute 'group'
# Error while translating 'Zand op het wegdek': 'NoneType' object has no attribute 'group'
# Error while translating 'Defecte vrachtwagen (en object op de weg en opruim/berging)': 'NoneType' object has no attribute 'group'
# Error while translating 'Ongeval (met schade RWS)': 'NoneType' object has no attribute 'group'
# Error while translating 'Extra verkeersdrukte door werkzaamheden elders': 'NoneType' object has no attribute 'group'
# Error while translating 'Ongeval (met file op omleidingsroute)': 'NoneType' object has no attribute 'group'
# Error while translating 'Incident op stedelijke weg': 'NoneType' object has no attribute 'group'
# Error while translating 'Defect voertuig (en files buiten spits zonder oorzaak)': 'NoneType' object has no attribute 'group'
# Error while translating 'Werkzaamheden op provinciale weg': 'NoneType' object has no attribute 'group'
# Error while translating 'Uitgelopen werkzaamheden': 'NoneType' object has no attribute 'group'
# Error while translating 'Brugopening (en daarna defect voertuig)': 'NoneType' object has no attribute 'group'
# Error while translating 'schade RWS (en spitsfile)': 'NoneType' object has no attribute 'group'
# Error while translating 'Politieonderzoek': 'NoneType' object has no attribute 'group'
# Error while translating 'File zonder oorzaak buiten de spits (met ongeval op aansluitende weg)': 'NoneType' object has no attribute 'group'
# Error while translating 'Spitsfile (en spoedreparatie)': 'NoneType' object has no attribute 'group'
# Error while translating 'Ongeval op stedelijke weg': 'NoneType' object has no attribute 'group'
# Error while translating 'Rijstrook voor hulpdiensten afgesloten': 'NoneType' object has no attribute 'group'
# Error while translating 'Betoging': 'NoneType' object has no attribute 'group'
# Error while translating 'Spitsfile (met ongeval vrachtwagen met opruim/berging)': 'NoneType' object has no attribute 'group'
# Error while translating 'Wegwerkzaamheden over de grens': 'NoneType' object has no attribute 'group'
# Error while translating 'Verkeerssituatie gewijzigd als gevolg van wegwerkzaamheden': 'NoneType' object has no attribute 'group'
# Error while translating 'Omgewaaide bo(o)m(en)': 'NoneType' object has no attribute 'group'
# Error while translating 'Ongeval vrachtwagen (met file buiten spits zonder oorzaak)': 'NoneType' object has no attribute 'group'
# Error while translating 'Incident (met opruim/berging)': 'NoneType' object has no attribute 'group'
# Error while translating 'Mist': 'NoneType' object has no attribute 'group'
# Error while translating 'Verkeerslichten werken niet goed': 'NoneType' object has no attribute 'group'
# Error while translating 'Ongeval op aansluitende weg met berging': 'NoneType' object has no attribute 'group'
# Error while translating 'Ongeval vrachtwagen (met incident)': 'NoneType' object has no attribute 'group'
# Error while translating 'Terugkerend vakantieverkeer': 'NoneType' object has no attribute 'group'
# Error while translating 'Spitsfile (met ongeval en object op de weg)': 'NoneType' object has no attribute 'group'
# Error while translating 'Ongevalsonderzoek': 'NoneType' object has no attribute 'group'
# Error while translating 'Spitsfile (met werkzaamheden)': 'NoneType' object has no attribute 'group'
# Error while translating 'Incident (ongeval vrachtwagen) en incident (defect voertuig)': 'NoneType' object has no attribute 'group'
# Error while translating 'Incident (in een spitsfile)': 'NoneType' object has no attribute 'group'
# Error while translating 'File op omleidingsroute (in een spitsfile)': 'NoneType' object has no attribute 'group'
# Error while translating 'Noodtoestand': 'NoneType' object has no attribute 'group'
# Error while translating 'Spitsfile (met defecte vrachtwagen)': 'NoneType' object has no attribute 'group'
# Error while translating 'Werkzaamheden (en file buiten spits zonder oorzaak)': 'NoneType' object has no attribute 'group'
# Error while translating 'Incident(en)': 'NoneType' object has no attribute 'group'
# Error while translating 'Ongeval (met opruim / berging en ongeval op aansluitende weg)': 'NoneType' object has no attribute 'group'
# Error while translating 'Schade aan viaduct': 'NoneType' object has no attribute 'group'
# Error while translating 'Incident op andere rijrichting': 'NoneType' object has no attribute 'group'
# Error while translating 'Object op de weg (met schade RWS)': 'NoneType' object has no attribute 'group'
# Error while translating 'Zware regenval': 'NoneType' object has no attribute 'group'
# Error while translating 'Brand in de buurt van de weg': 'NoneType' object has no attribute 'group'
# Error while translating 'Spitsfile (met file op omleidingsroute)': 'NoneType' object has no attribute 'group'
# Error while translating 'Gekantelde caravan': 'NoneType' object has no attribute 'group'
# Error while translating 'Verkeer ingesloten tussen afrit en incident': 'NoneType' object has no attribute 'group'
# Error while translating 'Hulpdienstvoertuigen': 'NoneType' object has no attribute 'group'
# Error while translating 'Bermbrand': 'NoneType' object has no attribute 'group'
# Error while translating 'Obstakel(s) op de weg {iets dat de weg of een deel ervan blo': 'NoneType' object has no attribute 'group'
# Error while translating 'Defect voertuig (met spoedreparatie)': 'NoneType' object has no attribute 'group'
# Error while translating 'Eerder incident op aansluitende weg': 'NoneType' object has no attribute 'group'
# Error while translating 'Spitsfile (met ongeval en ongeval op aansluitende weg)': 'NoneType' object has no attribute 'group'
# Error while translating 'Concert': 'NoneType' object has no attribute 'group'
# Error while translating 'Geschaarde caravan('s)': 'NoneType' object has no attribute 'group'
# Error while translating 'Incident (object op de weg) en Files buiten spits zonder oorzaak': 'NoneType' object has no attribute 'group'
# Error while translating 'schade RWS en files buiten spits zonder oorzaak': 'NoneType' object has no attribute 'group'
# Error while translating 'Gekantelde aanhangwagen': 'NoneType' object has no attribute 'group'
# Error while translating 'Werkzaamheden aan geleiderail': 'NoneType' object has no attribute 'group'
# Error while translating 'Werkzaamheden in de berm': 'NoneType' object has no attribute 'group'
# Error while translating 'Ongeval (met file op omleidingsroute) (en file zonder oorzaak)': 'NoneType' object has no attribute 'group'
# Error while translating 'Spitsfile (met ongeval vrachtwagen)': 'NoneType' object has no attribute 'group'
# Error while translating 'Ongeval (len) met olielekkage': 'NoneType' object has no attribute 'group'
# Error while translating 'Werkzaamheden aan kunstwerken': 'NoneType' object has no attribute 'group'
# Error while translating 'Evenementen (en spitsfile)': 'NoneType' object has no attribute 'group'
# Error while translating 'Spitsstrook aan de linkerzijde gesloten': 'NoneType' object has no attribute 'group'
# Error while translating 'ongeval (met spoedreparatie)': 'NoneType' object has no attribute 'group'
# Error while translating 'Defect voertuig (met file op omleidingsroute)': 'NoneType' object has no attribute 'group'
# Error while translating 'Ongeval vrachtwagen (met ongeval op aansluitende weg)': 'NoneType' object has no attribute 'group'
# Error while translating 'Defect voertuig (met incident op aansluitende weg)': 'NoneType' object has no attribute 'group'
# Error while translating 'Spitsstrook aan de rechterzijde gesloten': 'NoneType' object has no attribute 'group'
# Error while translating 'Ongeval vrachtwagen (met schade RWS)': 'NoneType' object has no attribute 'group'
# Error while translating 'Werkzaamheden (in een spitsfile)': 'NoneType' object has no attribute 'group'
# Error while translating 'Falen DVM (na brugopening)': 'NoneType' object has no attribute 'group'
# Error while translating 'File op omleidingsroute (agv werkzaamheden)': 'NoneType' object has no attribute 'group'
# Error while translating 'Ongeval (en daarna werkzaamheden)': 'NoneType' object has no attribute 'group'
# Error while translating 'Schade aan tunnel': 'NoneType' object has no attribute 'group'
# Error while translating 'Rijstrooksignalering werkt niet goed': 'NoneType' object has no attribute 'group'
# Error while translating 'Spookrijder(s)': 'NoneType' object has no attribute 'group'
# Error while translating 'Verkeerslichten buiten werking': 'NoneType' object has no attribute 'group'
# Error while translating 'File op omleidingsroute (agv spoedreparatie)': 'NoneType' object has no attribute 'group'
# Error while translating 'Opruimwerkzaamheden (achteraf door VWM opgegeven)': 'NoneType' object has no attribute 'group'
# Error while translating 'Langdurige wegwerkzaamheden': 'NoneType' object has no attribute 'group'
# Error while translating 'Spitsfile (en schade RWS)': 'NoneType' object has no attribute 'group'
# Error while translating 'Te hoog voertuig gesignaleerd, wordt afgehandeld': 'NoneType' object has no attribute 'group'
# Error while translating 'Ongeval (en politie controle)': 'NoneType' object has no attribute 'group'
# Error while translating 'Bevriezing van natte weggedeelten': 'NoneType' object has no attribute 'group'
# Error while translating 'Spitsfile (met defect voertuig en ongeval op aansluitende weg)': 'NoneType' object has no attribute 'group'
# C:\Users\timom\AppData\Local\Temp\ipykernel_13476\4078264657.py:51: FutureWarning: Returning a DataFrame from Series.apply when the supplied function returns a Series is deprecated and will be removed in a future version.
#   data['Cause Progression'] = data['Cause Progression'].apply(extract_vwm)
#    NL Site Number File Start Date File End Date File Start Time File End Time  \
# 0         3346718      2023-01-11    2023-01-11        17:22:32      17:44:04
# 1         3346719      2023-01-11    2023-01-11        17:22:32      17:43:00
# 2         3346720      2023-01-11    2023-01-11        17:22:32      17:59:00
# 3         3346721      2023-01-11    2023-01-11        17:22:32      17:30:04
# 4         3346722      2023-01-11    2023-01-11        17:22:32      17:24:00
# 5         3346809      2023-01-11    2023-01-11        17:36:33      17:39:00
# 6         3346811      2023-01-11    2023-01-11        17:36:33      17:38:00
# 7         3346812      2023-01-11    2023-01-11        17:36:33      17:38:00
# 8         3346813      2023-01-11    2023-01-11        17:36:33      17:38:00
# 9         3346816      2023-01-11    2023-01-11        17:37:32      17:39:00
#
#    File Severity  Average Length File Duration  Hectometer Head  \
# 0        58340.0       2709000.0        21,533            116.5
# 1        74363.0       3633000.0        20,467              0.0
# 2       213030.0       5842000.0        36,467             70.0
# 3        20768.0       2757000.0         7,533              9.8
# 4         3080.0       2100000.0         1,467            223.2
# 5         5145.0       2100000.0         2,450             59.6
# 6         4205.0       2900000.0         1,450              8.1
# 7         3425.0       2362000.0         1,450            142.6
# 8         3915.0       2700000.0         1,450             21.3
# 9         3373.0       2300000.0         1,467             22.5
#
#    Hectometer Tail Route Letter  Route Number Route Description  \
# 0            114.5            A             2                A2
# 1              3.7            A            28               A28
# 2             66.6            A             6                A6
# 3             12.2            A            76               A76
# 4            225.3            N            18               N18
# 5             57.5            A             2                A2
# 6              5.2            A            44               A44
# 7            140.2            A            59               A59
# 8             24.0            N            35               N35
# 9             24.7            A            16               A16
#
#   Hectometering Direction   Trajectory From     Trajectory To  \
# 0                oplopend           Utrecht  's-Hertogenbosch
# 1                aflopend        Amersfoort           Utrecht
# 2                oplopend            Muiden          Lelystad
# 3                aflopend              Aken            Geleen
# 4                aflopend          Enschede        Varsseveld
# 5                oplopend         Amsterdam           Utrecht
# 6                oplopend         Amsterdam         Wassenaar
# 7                oplopend  's-Hertogenbosch               Oss
# 8                aflopend            Almelo            Zwolle
# 9                aflopend             Breda         Rotterdam
#
#                          Cause Ground Detail
# 0                                       None
# 1  rush hour traffic jam (no cause reported)
# 2  rush hour traffic jam (no cause reported)
# 3  rush hour traffic jam (no cause reported)
# 4  rush hour traffic jam (no cause reported)
# 5  rush hour traffic jam (no cause reported)
# 6  rush hour traffic jam (no cause reported)
# 7  rush hour traffic jam (no cause reported)
# 8  rush hour traffic jam (no cause reported)
# 9  rush hour traffic jam (no cause reported)

# %% [markdown]
# Yet again the changes are succesfull and now the column is more easily acceptable.

# %%
# import pandas as pd

# # Load the dataset
# file_path = './translated_cause_ground_detail_combined_data.csv'
# data = pd.read_csv(file_path)


# # Define a function to extract the 'VWM' part
# def extract_vwm(value):
#     if pd.isna(value) or not isinstance(value, str):
#         return value  # Return the value as is if it's NaN or not a string
#     # Extract 'VWM' followed by any number of digits
#     vwm_part = pd.Series(value).str.extract(r'(VWM \d+)')[0]
#     return vwm_part

# # Apply the function to the 'Cause Progression' column
# data['Cause Progression'] = data['Cause Progression'].apply(extract_vwm)


# # Save the modified dataset
# modified_file_path = './modified_cause_progression.csv'
# data.to_csv(modified_file_path, index=False)

# %% [markdown]
# Here I apply filtering for routes only for Maarheeze and Eindhoven.

# %%
file_path = './data_final_yes.csv'
data = pd.read_csv(file_path)


data = data[
    (data["Route Description"] == "A2") &
    (data['Hectometer Head'] < 182.0) &
    (data['Hectometer Tail'] > 155.0) &
    (data['Hectometering Direction'] == 'descending')
]

data['route'] = "E-D"

modified_file_path = './Timo-Maarheeze-Eindhoven.csv'
data.to_csv(modified_file_path, index=False)
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 0 entries
# Data columns (total 18 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   NL Site Number           0 non-null      int64
#  1   File Start Date          0 non-null      object
#  2   File End Date            0 non-null      object
#  3   File Start Time          0 non-null      object
#  4   File End Time            0 non-null      object
#  5   File Severity            0 non-null      float64
#  6   Average Length           0 non-null      float64
#  7   File Duration            0 non-null      object
#  8   Hectometer Head          0 non-null      float64
#  9   Hectometer Tail          0 non-null      float64
#  10  Route Letter             0 non-null      object
#  11  Route Number             0 non-null      int64
#  12  Route Description        0 non-null      object
#  13  Hectometering Direction  0 non-null      object
#  14  Trajectory From          0 non-null      object
#  15  Trajectory To            0 non-null      object
#  16  Cause Ground Detail      0 non-null      object
#  17  route                    0 non-null      object
# dtypes: float64(4), int64(2), object(12)
# memory usage: 0.0+ bytes

# %% [markdown]
# Here I translate the data.

# %%
# import pandas as pd

# # Load the dataset
# file_path = './filteredData.csv' 
# data = pd.read_csv(file_path)



# # Save the translated dataset
# translated_file_path = './translated_causes.csv'
# data.to_csv(translated_file_path, index=False)

# print("Translation complete. Translated data saved to:", translated_file_path)

# %% [markdown]
# and finaly I am going to drop the useless columns like Couse Code Progression and Cause Code

# %%
# file_path = './translated_causes.csv' 
# data = pd.read_csv(file_path)
# data.drop(columns=["Cause Code Progression", "Cause Code"], inplace=True)

# final_data = './final.csv'
# data.to_csv(final_data, index=False)

# %% [markdown]
# The needed road is A2 so I will also filter on that road.

# %%
# file_path = './final.csv'
# data = pd.read_csv(file_path)
# data = data[data["Route Description"] == "A2"]

# data.head





# final_data = './A2data.csv'
# data.to_csv(final_data, index=False)

# %% [markdown]
# The data here is from Maarheeze to Eindhoven so I will add a new column that indicates that information. The column will store the value "M-E"

# %%
# file_path = './A2data.csv'
# data = pd.read_csv(file_path)

# data['route'] = "M-E"

# final_data = './dataWithColumn.csv'

# data.to_csv(final_data, index=False)

# %% [markdown]
# Now I will filter the data for Eindhoven to Den bosh and apply the same logic

# %%
file_path = './data_final_yes.csv'
data = pd.read_csv(file_path)

data = data[
    (data["Route Description"] == "A2") &
    (data['Hectometer Head'] < 154.8) &
    (data['Hectometer Tail'] > 112.8) &
    (data['Hectometering Direction'] == 'descending')
]

data['route'] = "E-D"

data.to_csv("./Timo-Eindhoven-DenBosch.csv", index=False)

# %% [markdown]
# Now let's translate the columns

# %%
# import pandas as pd

# # Load the dataset
# file_path = './dataEindhovenDenBosch.csv' 
# data = pd.read_csv(file_path)



# translation_dict = {
#     'Aanleg en gepland onderhoud': 'Construction and Planned Maintenance',
#     'Acties of demonstraties': 'Actions or Demonstrations',
#     'Afremmend verkeer als gevolg van kijkers naar ongeval(len)': 'Traffic Slowing Down Due to Onlookers at Accidents',
#     'Andere wegbeheerder': 'Other Road Manager',
#     'Bermbrand': 'Roadside Fire',
#     'Betoging': 'Protest',
#     'Brand in de buurt van de weg': 'Fire Near the Road',
#     'Brandend(e) voertuig(en)': 'Burning Vehicle(s)',
#     'Cultureel evenement': 'Cultural Event',
#     'Defect voertuig': 'Defective Vehicle',
#     'Defect(e) voertuig(en)': 'Defective Vehicle(s)',
#     'Defecte bus(sen)': 'Defective Bus(es)',
#     'Defecte vrachtwagen': 'Defective Truck',
#     'Defecte vrachtwagen(s)': 'Defective Truck(s)',
#     'Drukte': 'Crowd or Busyness',
#     'Eerder pechgeval': 'Earlier Breakdown',
#     'Eerder(e) ongeval(len)': 'Previous Accident(s)',
#     'Er ligt rommel op de weg': 'Clutter on the Road',
#     'Evenement': 'Event',
#     'Extra verkeersdrukte door verkeer dat een omleiding volgt': 'Extra Traffic Due to Traffic Following a Diversion',
#     'Falen Infra': 'Infrastructure Failure',
#     'Festival': 'Festival',
#     'File buiten spits (geen oorzaak gemeld)': 'Off-Peak Traffic Jam (No Cause Reported)',
#     'Gekanteld(e) voertuig(en)': 'Tilted Vehicle(s)',
#     'Gekantelde aanhangwagen': 'Tilted Trailer',
#     'Gevaarlijke situatie': 'Dangerous Situation',
#     'Hoge intensiteit': 'High Intensity',
#     'Incident (gestrand voertuig)': 'Incident (Stranded Vehicle)',
#     'Incident (obstakel op de weg)': 'Incident (Obstacle on the Road)',
#     'Incident (opruimwerkzaamheden)': 'Incident (Cleanup Operations)',
#     'Incident elders': 'Incident Elsewhere',
#     'Incident op aansluitende weg': 'Incident on Connecting Road',
#     'Kijkfile': 'Rubbernecking Traffic Jam',
#     'Lading op de weg': 'Load on the Road',
#     'Langdurige wegwerkzaamheden': 'Long-Term Roadworks',
#     'Langza(a)m(e) voertuig(en)': 'Slow-Moving Vehicle(s)',
#     'Olie op het wegdek': 'Oil on the Road Surface',
#     'Ongeval op provinciale weg': 'Accident on Provincial Road',
#     'Ongevalsafhandeling': 'Accident Handling',
#     'Ongevalsonderzoek': 'Accident Investigation',
#     'Opruimingswerkzaamheden': 'Cleanup Operations',
#     'Overige oorzaken': 'Other Causes',
#     'Politieactie': 'Police Action',
#     'Politieonderzoek': 'Police Investigation',
#     'Provinciale weg': 'Provincial Road',
#     'Recreatie- en vakantieverkeer': 'Recreational and Holiday Traffic',
#     'Slecht wegdek': 'Poor Road Surface',
#     'Vakantieverkeer': 'Holiday Traffic',
#     'Vloeistof op de weg': 'Liquid on the Road',
#     'Vloeistof op het wegdek': 'Liquid on the Road Surface',
#     'Water op de weg': 'Water on the Road',
#     'Wegdek in slechte toestand': 'Road Surface in Poor Condition',
#     'Werkzaamheden elders': 'Works Elsewhere',
#     'Werkzaamheden op aansluitende weg': 'Works on Connecting Road',
#     'Geen oorzaak gemeld': 'No Cause Reported',
#     'Incident': 'Incident',
#     'Ongepland onderhoud': 'Unplanned Maintenance',
#     'Ongeval': 'Accident',
#     'Ongeval elders': 'Accident Elsewhere',
#     'Ongeval met vrachtwagen(s)': 'Accident with Truck(s)',
#     'Ongeval op aansluitende weg': 'Accident on Connecting Road',
#     'Ongeval vrachtwagen': 'Truck Accident',
#     'Ongeval(len)': 'Accidents',
#     'Spitsfile (geen oorzaak gemeld)': 'Rush Hour Traffic Jam (No Cause Reported)',
#     'Spitsfile (geen oorzaak gemeld) met gevonden werk in Spin': 'Rush Hour Traffic Jam (No Cause Reported) with Found Work in Spin',
#     'Spoedreparatie': 'Emergency Repair',
#     'Voorwerpen op de weg': 'Objects on the Road',
#     'Wegwerkzaamheden': 'Road Works',
#     'Werkzaamheden': 'Works',
#     'Werkzaamheden gevonden door WiFi-script': 'Works Detected by WiFi Script'
# }




# # List of columns to translate
# columns_to_translate = ['Cause 1', 'Cause 2', 'Cause 3', 'Cause 4']

# # Apply manual translation to each column
# for col in columns_to_translate:
#     data[col] = data[col].map(translation_dict).fillna(data[col])

# # Save the translated dataset
# translated_file_path = './translatedDataEindhovenDenBosch.csv'
# data.to_csv(translated_file_path, index=False)

# print("Translation complete. Translated data saved to:", translated_file_path)

# %% [markdown]
# now I am going to drop the useless columns

# %%
# file_path = './translatedDataEindhovenDenBosch.csv' 
# data = pd.read_csv(file_path)
# data.drop(columns=["Cause Code Progression", "Cause Code"], inplace=True)

# final_data = './droppedcolumnsEindhivenDenBosch.csv'
# data.to_csv(final_data, index=False)

# %% [markdown]
# The highway from Eindhoven to Den Bosch is number A2 so I am going to filter the data on that road.

# %%
# file_path = './droppedcolumnsEindhivenDenBosch.csv'
# data = pd.read_csv(file_path)
# data = data[data["Route Description"] == "A2"]

# data.head





# final_data = './A2dataEindhovenDenBosch.csv'
# data.to_csv(final_data, index=False)

# %% [markdown]
# Now I am going to add a column to specify that the data here is from Eindhoven to Den Bosch

# %%
# file_path = './A2dataEindhovenDenBosch.csv'
# data = pd.read_csv(file_path)



# final_data = './dataEindhovenDenBosch.csv'

# data.to_csv(final_data, index=False)

# %% [markdown]
# Now I will filter the data for Eindhoven to Arnhem and apply the same logic

# %%
file_path = './data_final_yes.csv'
data = pd.read_csv(file_path)

data = data[
    (data["Route Description"] == "A50") &
    (data['Hectometer Head'] < 162.2) &
    (data['Hectometer Tail'] > 93.5) &
    (data['Hectometering Direction'] == 'ascending')
]

data['route'] = "E-A"

data.to_csv("./Timo-Eindhoven-Arnhem.csv", index=False)

# %% [markdown]
# Now I will translate the data.

# %%
# import pandas as pd

# # Load the dataset
# file_path = './dataEindhovenArnhem.csv' 
# data = pd.read_csv(file_path)



# translation_dict = {
#     'Aanleg en gepland onderhoud': 'Construction and Planned Maintenance',
#     'Acties of demonstraties': 'Actions or Demonstrations',
#     'Afremmend verkeer als gevolg van kijkers naar ongeval(len)': 'Traffic Slowing Down Due to Onlookers at Accidents',
#     'Andere wegbeheerder': 'Other Road Manager',
#     'Bermbrand': 'Roadside Fire',
#     'Betoging': 'Protest',
#     'Brand in de buurt van de weg': 'Fire Near the Road',
#     'Brandend(e) voertuig(en)': 'Burning Vehicle(s)',
#     'Cultureel evenement': 'Cultural Event',
#     'Defect voertuig': 'Defective Vehicle',
#     'Defect(e) voertuig(en)': 'Defective Vehicle(s)',
#     'Defecte bus(sen)': 'Defective Bus(es)',
#     'Defecte vrachtwagen': 'Defective Truck',
#     'Defecte vrachtwagen(s)': 'Defective Truck(s)',
#     'Drukte': 'Crowd or Busyness',
#     'Eerder pechgeval': 'Earlier Breakdown',
#     'Eerder(e) ongeval(len)': 'Previous Accident(s)',
#     'Er ligt rommel op de weg': 'Clutter on the Road',
#     'Evenement': 'Event',
#     'Extra verkeersdrukte door verkeer dat een omleiding volgt': 'Extra Traffic Due to Traffic Following a Diversion',
#     'Falen Infra': 'Infrastructure Failure',
#     'Festival': 'Festival',
#     'File buiten spits (geen oorzaak gemeld)': 'Off-Peak Traffic Jam (No Cause Reported)',
#     'Gekanteld(e) voertuig(en)': 'Tilted Vehicle(s)',
#     'Gekantelde aanhangwagen': 'Tilted Trailer',
#     'Gevaarlijke situatie': 'Dangerous Situation',
#     'Hoge intensiteit': 'High Intensity',
#     'Incident (gestrand voertuig)': 'Incident (Stranded Vehicle)',
#     'Incident (obstakel op de weg)': 'Incident (Obstacle on the Road)',
#     'Incident (opruimwerkzaamheden)': 'Incident (Cleanup Operations)',
#     'Incident elders': 'Incident Elsewhere',
#     'Incident op aansluitende weg': 'Incident on Connecting Road',
#     'Kijkfile': 'Rubbernecking Traffic Jam',
#     'Lading op de weg': 'Load on the Road',
#     'Langdurige wegwerkzaamheden': 'Long-Term Roadworks',
#     'Langza(a)m(e) voertuig(en)': 'Slow-Moving Vehicle(s)',
#     'Olie op het wegdek': 'Oil on the Road Surface',
#     'Ongeval op provinciale weg': 'Accident on Provincial Road',
#     'Ongevalsafhandeling': 'Accident Handling',
#     'Ongevalsonderzoek': 'Accident Investigation',
#     'Opruimingswerkzaamheden': 'Cleanup Operations',
#     'Overige oorzaken': 'Other Causes',
#     'Politieactie': 'Police Action',
#     'Politieonderzoek': 'Police Investigation',
#     'Provinciale weg': 'Provincial Road',
#     'Recreatie- en vakantieverkeer': 'Recreational and Holiday Traffic',
#     'Slecht wegdek': 'Poor Road Surface',
#     'Vakantieverkeer': 'Holiday Traffic',
#     'Vloeistof op de weg': 'Liquid on the Road',
#     'Vloeistof op het wegdek': 'Liquid on the Road Surface',
#     'Water op de weg': 'Water on the Road',
#     'Wegdek in slechte toestand': 'Road Surface in Poor Condition',
#     'Werkzaamheden elders': 'Works Elsewhere',
#     'Werkzaamheden op aansluitende weg': 'Works on Connecting Road',
#     'Geen oorzaak gemeld': 'No Cause Reported',
#     'Incident': 'Incident',
#     'Ongepland onderhoud': 'Unplanned Maintenance',
#     'Ongeval': 'Accident',
#     'Ongeval elders': 'Accident Elsewhere',
#     'Ongeval met vrachtwagen(s)': 'Accident with Truck(s)',
#     'Ongeval op aansluitende weg': 'Accident on Connecting Road',
#     'Ongeval vrachtwagen': 'Truck Accident',
#     'Ongeval(len)': 'Accidents',
#     'Spitsfile (geen oorzaak gemeld)': 'Rush Hour Traffic Jam (No Cause Reported)',
#     'Spitsfile (geen oorzaak gemeld) met gevonden werk in Spin': 'Rush Hour Traffic Jam (No Cause Reported) with Found Work in Spin',
#     'Spoedreparatie': 'Emergency Repair',
#     'Voorwerpen op de weg': 'Objects on the Road',
#     'Wegwerkzaamheden': 'Road Works',
#     'Werkzaamheden': 'Works',
#     'Werkzaamheden gevonden door WiFi-script': 'Works Detected by WiFi Script'
# }




# # List of columns to translate
# columns_to_translate = ['Cause 1', 'Cause 2', 'Cause 3', 'Cause 4']

# # Apply manual translation to each column
# for col in columns_to_translate:
#     data[col] = data[col].map(translation_dict).fillna(data[col])

# # Save the translated dataset
# translated_file_path = './translatedDataEindhovenArnhem.csv'
# data.to_csv(translated_file_path, index=False)

# print("Translation complete. Translated data saved to:", translated_file_path)

# %% [markdown]
# now I am going to drop the useless columns

# %%
# file_path = './translatedDataEindhovenArnhem.csv' 
# data = pd.read_csv(file_path)
# data.drop(columns=["Cause Code Progression", "Cause Code"], inplace=True)

# final_data = './droppedcolumnsEindhivenArnhem.csv'
# data.to_csv(final_data, index=False)

# %% [markdown]
# The highway from Eindhoven to Arnhem is number A50 so I am going to filter the data on that road.

# %%
# file_path = './droppedcolumnsEindhivenArnhem.csv'
# data = pd.read_csv(file_path)
# data = data[data["Route Description"] == "A50"]

# data.head





# final_data = './A50dataEindhovenArnhem.csv'
# data.to_csv(final_data, index=False)

# %% [markdown]
# Now I am going to add a column to specify that the data here is from Eindhoven to Arnhem

# %%
# file_path = './A50dataEindhovenArnhem.csv'
# data = pd.read_csv(file_path)

# data['route'] = "E-A"

# final_data = './dataEindhovenArnhemColumn.csv'

# data.to_csv(final_data, index=False)
